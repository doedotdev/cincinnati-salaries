# %% [markdown]
# ### Cincinnati Salaries
# - https://data.cincinnati-oh.gov/Efficient-Service-Delivery/City-of-Cincinnati-Employees-w-Salaries/wmj4-ygbf

# %%
! pip install sodapy
! pip install pandas
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...

# %%
import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cincinnati-oh.gov", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cincinnati-oh.gov,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("wmj4-ygbf", limit=10000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df
# Out:
#      age_range                       name sex                    race  \
# 0        61-70               Klumb,Gail L   F                   WHITE
# 1        31-40               Davis,Philip   M                   WHITE
# 2        31-40              Stone,Erica M   F                   WHITE
# 3        26-30            Merritt,Tyler W   M                   WHITE
# 4        31-40             Hawkins,Amy S.   F                   WHITE
# ...        ...                        ...  ..                     ...
# 6533     31-40  Florimonte,Michael Parker   M                   WHITE
# 6534     31-40         Predmore,Steven R.   M                   WHITE
# 6535     41-50       Sukovaty,Matthew Kit   M                   WHITE
# 6536     51-60            Jones II,Lonnie   M                   BLACK
# 6537     51-60         Aparajit,Rashmi V.   F  ASIAN/PACIFIC ISLANDER
#
#                      business_title   deptid jobcode position_nbr    location  \
# ...

# %%
max(pd.to_numeric(results_df['annual_rt']))
# Out:
# 247554.52800000002
